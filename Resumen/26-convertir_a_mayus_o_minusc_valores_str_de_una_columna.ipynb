# %% [markdown]
# ### **26 - Convertir a mayúsculas o minúsculas valores str de columnas de un Dataframe**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### **`Convertir valores str de las columnas en MAYUSCULAS`**

# %% [markdown]
# - Para convertir en minusculas, es el mismo proceso pero utilizando el metodo **`lower()`**

# %%
df = pd.read_csv('worldcup2014.csv')
df.shape
# Out:
# (32, 13)

# %%
df.head()
# Out:
#           team     continent group  group_pos  cantidad_juegos  \
# 0       Brazil  southamerica     A          1                3
# 1       Mexico  northamerica     A          2                3
# 2      Croatia        europe     A          3                3
# 3     Cameroon        africa     A          4                3
# 4  Netherlands        europe     B          1                3
#
#    juegos_ganados  juegos_empatados  juegos_perdidos  goles_favor  \
# 0               2                 1                0            7
# 1               2                 1                0            4
# 2               1                 0                2            6
# 3               0                 0                3            1
# 4               3                 0                0           10
#
#    goles_contra goles_diferencia  puntos  clasificado
# 0             2                5       7            1
# 1             1                3       7            1
# ...

# %%
df['team'].str.upper()
# Out:
# 0                     BRAZIL
# 1                     MEXICO
# 2                    CROATIA
# 3                   CAMEROON
# 4                NETHERLANDS
# 5                      CHILE
# 6                      SPAIN
# 7                  AUSTRALIA
# 8                   COLOMBIA
# 9                     GREECE
# 10               IVORY COAST
# 11                     JAPAN
# 12                COSTA RICA
# 13                   URUGUAY
# 14                     ITALY
# 15                   ENGLAND
# 16                    FRANCE
# 17               SWITZERLAND
# 18                   ECUADOR
# 19                  HONDURAS
# 20                 ARGENTINA
# 21                   NIGERIA
# 22    BOSNIA AND HERZEGOVINA
# 23                      IRAN
# 24                   GERMANY
# 25             UNITED STATES
# 26                  PORTUGAL
# 27                     GHANA
# 28                   BELGIUM
# 29                   ALGERIA
# 30                    RUSSIA
# 31               SOUTH KOREA
# ...

# %%
df.loc[:, ['team']] = df['team'].str.upper()

# %%
df
# Out:
#                       team     continent group  group_pos  cantidad_juegos  \
# 0                   BRAZIL  southamerica     A          1                3
# 1                   MEXICO  northamerica     A          2                3
# 2                  CROATIA        europe     A          3                3
# 3                 CAMEROON        africa     A          4                3
# 4              NETHERLANDS        europe     B          1                3
# 5                    CHILE  southamerica     B          2                3
# 6                    SPAIN        europe     B          3                3
# 7                AUSTRALIA          asia     B          4                3
# 8                 COLOMBIA  southamerica     C          1                3
# 9                   GREECE        europe     C          2                3
# 10             IVORY COAST        africa     C          3                3
# ...

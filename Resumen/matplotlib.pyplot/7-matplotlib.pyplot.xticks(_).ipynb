# %% [markdown]
# ### **7 - Matplotlib.pyplot.xticks( )**

# %% [markdown]
# #### **`Matplotlib.pyplot.xticks()`**

# %% [markdown]
# La función **`xticks()`** del módulo pyplot de la biblioteca matplotlib se utiliza para obtener y establecer las ubicaciones y etiquetas actuales del eje x.

# %% [markdown]
# #### **`Sintaxis de Matplotlib pyplot.xticks()`**

# %% [markdown]
# **`Sintaxis`**:
#
# > **matplotlib.pyplot.xticks**(**ticks**=None, **labels**=None, ****kwargs**)
#
# **`Parámetros`**: Este método acepta los siguientes parámetros que se describen a continuación:
#
# - **`ticks`**: Este parámetro es la lista de ubicaciones de xtick y un parámetro opcional. Si se pasa una lista vacía como argumento entonces eliminará todos los xticks
#
# - **`labels`**: Este parámetro contiene las etiquetas a colocar en las ubicaciones de los ticks dados. Y es un parámetro opcional.
#
# - **`**kwargs`**: Este parámetro es una propiedad de texto que se utiliza para controlar la apariencia de las etiquetas.
#
# **`Returns`**: Devuelve lo siguiente:
#
# - **`locs`**: Devuelve la lista de posiciones de ytick.
# - **`labels`** :Devuelve la lista de objetos de texto ylabel.

# %% [markdown]
# #### **`Ejemplos`**

# %% [markdown]
# ##### **Ejemplo 1**

# %%
import numpy as np 
import matplotlib.pyplot as plt 
	
x = [1, 2, 3, 4] 
y = [95, 38, 54, 35] 
labels = ['Geeks1', 'Geeks2', 'Geeks3', 'Geeks4'] 

plt.plot(x, y) 

# Puede especificar una rotación para las etiquetas de tick en grados o con keywords. 
plt.xticks(x, labels, rotation ='vertical') 

# Rellenar los márgenes para que los marcadores no queden recortados por los ejes
plt.margins(0.2) 

# Ajusta el espaciado para evitar el recorte de las etiquetas.
plt.subplots_adjust(bottom = 0.15) 
plt.show()

# %% [markdown]
# ##### **Ejemplo 2**

# %%
import numpy as np 
import matplotlib.pyplot as plt 
	
x = [1, 2, 3, 4] 
y = [95, 38, 54, 35] 
labels = ['Geeks1', 'Geeks2', 'Geeks3', 'Geeks4'] 

plt.plot(x, y) 

# Puede especificar una rotación para las etiquetas de tick en grados o con keywords. 
plt.xticks(x, labels, rotation ='horizontal') 

# Rellenar los márgenes para que los marcadores no queden recortados por los ejes
plt.margins(0.2) 

# Ajusta el espaciado para evitar el recorte de las etiquetas.
plt.subplots_adjust(bottom = 0.15) 
plt.show()

# %% [markdown]
# ##### **Ejemplo 3**

# %%
import numpy as np 
import matplotlib.pyplot as plt 
	
x = [1, 2, 3, 4] 
y = [95, 38, 54, 35] 
labels = ['Geeks1', 'Geeks2', 'Geeks3', 'Geeks4'] 

plt.plot(x, y) 

# Puede especificar una rotación para las etiquetas de tick en grados o con keywords. 
plt.xticks(x, labels, rotation = 45) 

# Rellenar los márgenes para que los marcadores no queden recortados por los ejes
plt.margins(0.2) 

# Ajusta el espaciado para evitar el recorte de las etiquetas.
plt.subplots_adjust(bottom = 0.15) 
plt.show()

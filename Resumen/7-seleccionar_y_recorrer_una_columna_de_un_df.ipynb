# %% [markdown]
# ### **7 - Seleccionar una columna de un Dataframe**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('flights.csv')

df
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %% [markdown]
# #### **`SERIE`**

# %% [markdown]
# #### **> `Seleccionar una columna de un Dataframe`**

# %%
df['passengers']
# Out:
# 0      112
# 1      118
# 2      132
# 3      129
# 4      121
#       ...
# 139    606
# 140    508
# 141    461
# 142    390
# 143    432
# Name: passengers, Length: 144, dtype: int64

# %% [markdown]
# #### **> `Recorrer una Serie`**

# %%
for i in df['passengers']:
    print(i, type(i))
# Out:
# 112 <class 'int'>
# 118 <class 'int'>
# 132 <class 'int'>
# 129 <class 'int'>
# 121 <class 'int'>
# 135 <class 'int'>
# 148 <class 'int'>
# 148 <class 'int'>
# 136 <class 'int'>
# 119 <class 'int'>
# 104 <class 'int'>
# 118 <class 'int'>
# 115 <class 'int'>
# 126 <class 'int'>
# 141 <class 'int'>
# 135 <class 'int'>
# 125 <class 'int'>
# 149 <class 'int'>
# 170 <class 'int'>
# 170 <class 'int'>
# 158 <class 'int'>
# 133 <class 'int'>
# 114 <class 'int'>
# 140 <class 'int'>
# 145 <class 'int'>
# 150 <class 'int'>
# 178 <class 'int'>
# 163 <class 'int'>
# 172 <class 'int'>
# 178 <class 'int'>
# 199 <class 'int'>
# 199 <class 'int'>
# 184 <class 'int'>
# 162 <class 'int'>
# 146 <class 'int'>
# 166 <class 'int'>
# 171 <class 'int'>
# 180 <class 'int'>
# 193 <class 'int'>
# 181 <class 'int'>
# 183 <class 'int'>
# 218 <class 'int'>
# 230 <class 'int'>
# 242 <class 'int'>
# 209 <class 'int'>
# 191 <class 'int'>
# 172 <class 'int'>
# 194 <class 'int'>
# 196 <class 'int'>
# 196 <class 'int'>
# ...

# %% [markdown]
# ### **8 - Devolver el numero de columnas de un Dataframe**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('flights.csv')
df
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %% [markdown]
# #### **`Forma 1`**

# %%
# Nos devuelve la dimension del Dataframe
df.shape
# Out:
# (144, 3)

# %%
df.shape[1]
# Out:
# 3

# %% [markdown]
# #### **`Forma 2`**

# %%
df.dtypes
# Out:
# year           int64
# month         object
# passengers     int64
# dtype: object

# %%
len(df.dtypes)
# Out:
# 3
